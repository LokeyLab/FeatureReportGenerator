# %%
import pandas as pd, numpy as np, os, sys, shutil

toProcess_path = "/mnt/c/Users/derfelt/Desktop/LokeyLabFiles/TargetMol/FrozenVersions/TargetMol_1-27_1uM+10uM_PMA+noPMA_HD_horizconcat-dropna_UMAPreduced.csv"

# %%
df = pd.read_csv(toProcess_path, index_col=0)
display(df)
# Out:
#                                  UMAP_0    UMAP_1    UMAP_2    UMAP_3  \
# Index
# DMSO._.NA._.A01._.SP7201      10.118037 -0.929886 -0.057252  0.811134
# DMSO._.NA._.A01._.SP7202       9.710061  9.834537  0.586484  0.067021
# DMSO._.NA._.A01._.SP7203      10.110483 -0.937853 -0.056390  0.796675
# DMSO._.NA._.A01._.SP7204       9.665293  9.723505  0.625698  0.018332
# DMSO._.NA._.A01._.SP7205       9.662983  9.725186  0.623041  0.061965
# ...                                 ...       ...       ...       ...
# well_R._.10uM._.P05._.SP7237   9.945632  9.904302  0.475787  0.195860
# T5468._.10uM._.P06._.SP7237    9.951532  9.896416  0.485669  0.167813
# T6603._.10uM._.P07._.SP7237    9.975569  9.880706  0.489752  0.087555
# T5400._.10uM._.P08._.SP7237    9.973740  9.880960  0.490258  0.096075
# T5110._.10uM._.P09._.SP7237    9.874825  9.794276  0.616776  0.234669
#
#                                 UMAP_4    UMAP_5    UMAP_6    UMAP_7  \
# Index
# ...
